# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 606

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
base_url = "https://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f'&q={city}&appid={weather_api_key}'
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(base_url,city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]['lat']
        city_lng = city_weather["coord"]['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | olonkinbyen
# Processing Record 2 of Set 1 | labrador city
# Processing Record 3 of Set 1 | port elizabeth
# Processing Record 4 of Set 1 | san antonio de pale
# Processing Record 5 of Set 1 | vilyuchinsk
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | college
# Processing Record 8 of Set 1 | benghazi
# Processing Record 9 of Set 1 | adamstown
# Processing Record 10 of Set 1 | sisimiut
# Processing Record 11 of Set 1 | st. john's
# Processing Record 12 of Set 1 | grytviken
# Processing Record 13 of Set 1 | blackmans bay
# Processing Record 14 of Set 1 | kavaratti
# Processing Record 15 of Set 1 | puerto ayora
# Processing Record 16 of Set 1 | port-aux-francais
# Processing Record 17 of Set 1 | barah
# Processing Record 18 of Set 1 | atafu village
# Processing Record 19 of Set 1 | englewood
# Processing Record 20 of Set 1 | margaret river
# Processing Record 21 of Set 1 | ust-nera
# Processing Record 22 of Set 1 | petropavlovsk-kamchatsky
# Processing Record 23 of Set 1 | pisco
# Processing Record 24 of Set 1 | sola
# Processing Record 25 of Set 1 | diffa
# Processing Record 26 of Set 1 | puerto natales
# Processing Record 27 of Set 1 | daru
# Processing Record 28 of Set 1 | kodiak
# Processing Record 29 of Set 1 | paranaiba
# Processing Record 30 of Set 1 | afaahiti
# Processing Record 31 of Set 1 | hamilton
# Processing Record 32 of Set 1 | tolanaro
# Processing Record 33 of Set 1 | urengoy
# Processing Record 34 of Set 1 | new norfolk
# Processing Record 35 of Set 1 | enewetak
# Processing Record 36 of Set 1 | sierra grande
# Processing Record 37 of Set 1 | linxia chengguanzhen
# Processing Record 38 of Set 1 | cockburn town
# Processing Record 39 of Set 1 | kruisfontein
# Processing Record 40 of Set 1 | mount gambier
# Processing Record 41 of Set 1 | stanley
# Processing Record 42 of Set 1 | hermanus
# Processing Record 43 of Set 1 | al bawiti
# Processing Record 44 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 45 of Set 1 | altai
# Processing Record 46 of Set 1 | edinburgh of the seven seas
# Processing Record 47 of Set 1 | waitangi
# Processing Record 48 of Set 1 | hawaiian paradise park
# Processing Record 49 of Set 1 | aldinga beach
# Processing Record 50 of Set 1 | manaure
# Processing Record 0 of Set 2 | jamestown
# Processing Record 1 of Set 2 | polyarnyy
# Processing Record 2 of Set 2 | cukai
# Processing Record 3 of Set 2 | greenville
# Processing Record 4 of Set 2 | fort frances
# Processing Record 5 of Set 2 | nabire
# Processing Record 6 of Set 2 | udachny
# Processing Record 7 of Set 2 | serdar
# Processing Record 8 of Set 2 | avarua
# Processing Record 9 of Set 2 | shangmei
# Processing Record 10 of Set 2 | san juan de la maguana
# Processing Record 11 of Set 2 | san pedro pochutla
# Processing Record 12 of Set 2 | cam ranh
# Processing Record 13 of Set 2 | longyearbyen
# Processing Record 14 of Set 2 | saint-philippe
# Processing Record 15 of Set 2 | gulf shores
# Processing Record 16 of Set 2 | walvis bay
# Processing Record 17 of Set 2 | surgut
# Processing Record 18 of Set 2 | ulladulla
# Processing Record 19 of Set 2 | salekhard
# Processing Record 20 of Set 2 | aktau
# Processing Record 21 of Set 2 | mocimboa
# Processing Record 22 of Set 2 | punta del este
# Processing Record 23 of Set 2 | 'alaqahdari dishu
# Processing Record 24 of Set 2 | barillas
# Processing Record 25 of Set 2 | mormugao
# Processing Record 26 of Set 2 | bilibino
# Processing Record 27 of Set 2 | dhalie
# Processing Record 28 of Set 2 | port mathurin
# Processing Record 29 of Set 2 | luderitz
# Processing Record 30 of Set 2 | qamdo
# Processing Record 31 of Set 2 | whitehorse
# Processing Record 32 of Set 2 | williams lake
# Processing Record 33 of Set 2 | 'ohonua
# City not found. Skipping...
# Processing Record 34 of Set 2 | fortuna
# Processing Record 35 of Set 2 | arraial do cabo
# Processing Record 36 of Set 2 | georgetown
# Processing Record 37 of Set 2 | lerwick
# Processing Record 38 of Set 2 | minas de marcona
# Processing Record 39 of Set 2 | chilecito
# Processing Record 40 of Set 2 | tralee
# Processing Record 41 of Set 2 | cabo san lucas
# Processing Record 42 of Set 2 | kulia village
# City not found. Skipping...
# Processing Record 43 of Set 2 | vilyuysk
# Processing Record 44 of Set 2 | gua musang
# Processing Record 45 of Set 2 | kapuskasing
# Processing Record 46 of Set 2 | albany
# Processing Record 47 of Set 2 | akjoujt
# Processing Record 48 of Set 2 | malango
# Processing Record 49 of Set 2 | coquimbo
# Processing Record 0 of Set 3 | selkirk
# Processing Record 1 of Set 3 | jiangzi
# Processing Record 2 of Set 3 | ancud
# Processing Record 3 of Set 3 | howrah
# Processing Record 4 of Set 3 | san martin
# Processing Record 5 of Set 3 | greymouth
# Processing Record 6 of Set 3 | bethel
# Processing Record 7 of Set 3 | codrington
# Processing Record 8 of Set 3 | san patricio
# Processing Record 9 of Set 3 | west island
# Processing Record 10 of Set 3 | mar del plata
# Processing Record 11 of Set 3 | rikaze
# Processing Record 12 of Set 3 | invercargill
# Processing Record 13 of Set 3 | quellon
# Processing Record 14 of Set 3 | ilulissat
# Processing Record 15 of Set 3 | arkalyk
# Processing Record 16 of Set 3 | freetown
# Processing Record 17 of Set 3 | tiksi
# Processing Record 18 of Set 3 | port alfred
# Processing Record 19 of Set 3 | mawlaik
# Processing Record 20 of Set 3 | tranovaho
# City not found. Skipping...
# Processing Record 21 of Set 3 | thompson
# Processing Record 22 of Set 3 | yarkovo
# Processing Record 23 of Set 3 | loiza
# Processing Record 24 of Set 3 | tevriz
# Processing Record 25 of Set 3 | chonchi
# Processing Record 26 of Set 3 | dalbandin
# Processing Record 27 of Set 3 | remire-montjoly
# Processing Record 28 of Set 3 | hithadhoo
# Processing Record 29 of Set 3 | port lincoln
# Processing Record 30 of Set 3 | westport
# Processing Record 31 of Set 3 | olinda
# Processing Record 32 of Set 3 | san mariano
# Processing Record 33 of Set 3 | san luis de la loma
# Processing Record 34 of Set 3 | puerto aysen
# Processing Record 35 of Set 3 | holualoa
# Processing Record 36 of Set 3 | wynyard
# Processing Record 37 of Set 3 | badger
# Processing Record 38 of Set 3 | acapulco de juarez
# Processing Record 39 of Set 3 | banda aceh
# Processing Record 40 of Set 3 | iqaluit
# Processing Record 41 of Set 3 | vadso
# Processing Record 42 of Set 3 | dunedin
# Processing Record 43 of Set 3 | champerico
# Processing Record 44 of Set 3 | beipiao
# Processing Record 45 of Set 3 | santa cecilia
# Processing Record 46 of Set 3 | colonia
# Processing Record 47 of Set 3 | lihue
# Processing Record 48 of Set 3 | harstad
# Processing Record 49 of Set 3 | piriapolis
# Processing Record 0 of Set 4 | fort bragg
# Processing Record 1 of Set 4 | punta arenas
# Processing Record 2 of Set 4 | losal
# Processing Record 3 of Set 4 | qaqortoq
# Processing Record 4 of Set 4 | yuzhno-kurilsk
# Processing Record 5 of Set 4 | talnakh
# Processing Record 6 of Set 4 | chernyshevskiy
# Processing Record 7 of Set 4 | mel'nikovo
# Processing Record 8 of Set 4 | fallon
# Processing Record 9 of Set 4 | worland
# Processing Record 10 of Set 4 | ribeira brava
# Processing Record 11 of Set 4 | lata
# Processing Record 12 of Set 4 | el granada
# Processing Record 13 of Set 4 | al kharijah
# Processing Record 14 of Set 4 | namdrik
# Processing Record 15 of Set 4 | bredasdorp
# Processing Record 16 of Set 4 | veraval
# Processing Record 17 of Set 4 | hilo
# Processing Record 18 of Set 4 | papatowai
# Processing Record 19 of Set 4 | bandarbeyla
# Processing Record 20 of Set 4 | namie
# Processing Record 21 of Set 4 | susuman
# Processing Record 22 of Set 4 | gilgit
# Processing Record 23 of Set 4 | inowroclaw
# Processing Record 24 of Set 4 | chibougamau
# Processing Record 25 of Set 4 | al qadarif
# Processing Record 26 of Set 4 | yagry
# City not found. Skipping...
# Processing Record 27 of Set 4 | cozumel
# Processing Record 28 of Set 4 | acarau
# Processing Record 29 of Set 4 | kerch
# Processing Record 30 of Set 4 | tursunzoda
# Processing Record 31 of Set 4 | varena
# Processing Record 32 of Set 4 | bhamo
# Processing Record 33 of Set 4 | burshtyn
# Processing Record 34 of Set 4 | laguna
# Processing Record 35 of Set 4 | mount pearl
# Processing Record 36 of Set 4 | veshenskaya
# Processing Record 37 of Set 4 | palembang
# Processing Record 38 of Set 4 | kibondo
# Processing Record 39 of Set 4 | lompoc
# Processing Record 40 of Set 4 | ribeira grande
# Processing Record 41 of Set 4 | namibe
# Processing Record 42 of Set 4 | kyshtovka
# Processing Record 43 of Set 4 | lloydminster
# Processing Record 44 of Set 4 | skhirate
# Processing Record 45 of Set 4 | buka
# Processing Record 46 of Set 4 | kapenguria
# Processing Record 47 of Set 4 | azov
# Processing Record 48 of Set 4 | vingt cinq
# City not found. Skipping...
# Processing Record 49 of Set 4 | yellowknife
# Processing Record 0 of Set 5 | grand falls-windsor
# Processing Record 1 of Set 5 | ulanhot
# Processing Record 2 of Set 5 | villa emilio carranza
# Processing Record 3 of Set 5 | richards bay
# Processing Record 4 of Set 5 | dwarka
# Processing Record 5 of Set 5 | azul
# Processing Record 6 of Set 5 | mandan
# Processing Record 7 of Set 5 | toga village
# City not found. Skipping...
# Processing Record 8 of Set 5 | island harbour
# Processing Record 9 of Set 5 | bol
# Processing Record 10 of Set 5 | galliano
# Processing Record 11 of Set 5 | iskateley
# Processing Record 12 of Set 5 | carnarvon
# Processing Record 13 of Set 5 | newman
# Processing Record 14 of Set 5 | alice springs
# Processing Record 15 of Set 5 | alpena
# Processing Record 16 of Set 5 | rukban
# City not found. Skipping...
# Processing Record 17 of Set 5 | geraldton
# Processing Record 18 of Set 5 | wonju
# Processing Record 19 of Set 5 | isafjordur
# Processing Record 20 of Set 5 | ullal
# Processing Record 21 of Set 5 | hinton
# Processing Record 22 of Set 5 | kayangel
# Processing Record 23 of Set 5 | saipan
# Processing Record 24 of Set 5 | xining
# Processing Record 25 of Set 5 | kill devil hills
# Processing Record 26 of Set 5 | laboulaye
# Processing Record 27 of Set 5 | fort mcmurray
# Processing Record 28 of Set 5 | coyuca de catalan
# Processing Record 29 of Set 5 | lethem
# Processing Record 30 of Set 5 | constantia
# Processing Record 31 of Set 5 | karsun
# Processing Record 32 of Set 5 | alesund
# Processing Record 33 of Set 5 | nyurba
# Processing Record 34 of Set 5 | nizhnyaya omka
# Processing Record 35 of Set 5 | sault ste. marie
# Processing Record 36 of Set 5 | kingston
# Processing Record 37 of Set 5 | fuvahmulah
# City not found. Skipping...
# Processing Record 38 of Set 5 | nkurenkuru
# City not found. Skipping...
# Processing Record 39 of Set 5 | gizo
# Processing Record 40 of Set 5 | tshabong
# Processing Record 41 of Set 5 | mariental
# Processing Record 42 of Set 5 | pont rouge
# Processing Record 43 of Set 5 | vorgashor
# Processing Record 44 of Set 5 | orchard homes
# Processing Record 45 of Set 5 | vicuna
# Processing Record 46 of Set 5 | flin flon
# Processing Record 47 of Set 5 | kailua-kona
# Processing Record 48 of Set 5 | taoudenni
# Processing Record 49 of Set 5 | manavalakurichi
# Processing Record 0 of Set 6 | caleta de carquin
# Processing Record 1 of Set 6 | wailua homesteads
# Processing Record 2 of Set 6 | bagan
# Processing Record 3 of Set 6 | ciudad constitucion
# Processing Record 4 of Set 6 | moss vale
# Processing Record 5 of Set 6 | nikolayevsk
# Processing Record 6 of Set 6 | utrik
# Processing Record 7 of Set 6 | springbok
# Processing Record 8 of Set 6 | gaalkacyo
# Processing Record 9 of Set 6 | galesong
# Processing Record 10 of Set 6 | kourou
# Processing Record 11 of Set 6 | broome
# Processing Record 12 of Set 6 | ginir
# Processing Record 13 of Set 6 | latehar
# Processing Record 14 of Set 6 | tukrah
# Processing Record 15 of Set 6 | armidale
# Processing Record 16 of Set 6 | ojinaga
# Processing Record 17 of Set 6 | urbania
# Processing Record 18 of Set 6 | forbes
# Processing Record 19 of Set 6 | valle hermoso
# Processing Record 20 of Set 6 | arkhangel'sk
# Processing Record 21 of Set 6 | baruun-urt
# Processing Record 22 of Set 6 | gutao
# Processing Record 23 of Set 6 | verkhniy baskunchak
# Processing Record 24 of Set 6 | tadine
# Processing Record 25 of Set 6 | ha'il
# Processing Record 26 of Set 6 | puerto carreno
# Processing Record 27 of Set 6 | koshekhabl'
# Processing Record 28 of Set 6 | amboasary
# Processing Record 29 of Set 6 | maumere
# Processing Record 30 of Set 6 | hihifo
# City not found. Skipping...
# Processing Record 31 of Set 6 | qrendi
# Processing Record 32 of Set 6 | christchurch
# Processing Record 33 of Set 6 | tazacorte
# Processing Record 34 of Set 6 | lockwood
# Processing Record 35 of Set 6 | nova sintra
# Processing Record 36 of Set 6 | opochka
# Processing Record 37 of Set 6 | huarmey
# Processing Record 38 of Set 6 | santa vitoria do palmar
# Processing Record 39 of Set 6 | gemena
# Processing Record 40 of Set 6 | dul'durga
# Processing Record 41 of Set 6 | candido mendes
# Processing Record 42 of Set 6 | anadyr
# Processing Record 43 of Set 6 | puerto ayacucho
# Processing Record 44 of Set 6 | tamworth
# Processing Record 45 of Set 6 | hami
# Processing Record 46 of Set 6 | buenaventura
# Processing Record 47 of Set 6 | thinadhoo
# Processing Record 48 of Set 6 | lebu
# Processing Record 49 of Set 6 | salinas
# Processing Record 0 of Set 7 | teknaf
# Processing Record 1 of Set 7 | puerto deseado
# Processing Record 2 of Set 7 | lazaro cardenas
# Processing Record 3 of Set 7 | port douglas
# Processing Record 4 of Set 7 | ves'yegonsk
# Processing Record 5 of Set 7 | northam
# Processing Record 6 of Set 7 | aasiaat
# Processing Record 7 of Set 7 | ubari
# Processing Record 8 of Set 7 | galle
# Processing Record 9 of Set 7 | punta cardon
# Processing Record 10 of Set 7 | manga
# Processing Record 11 of Set 7 | pangoa
# Processing Record 12 of Set 7 | gamba
# Processing Record 13 of Set 7 | voi
# Processing Record 14 of Set 7 | yarmouth
# Processing Record 15 of Set 7 | leh
# Processing Record 16 of Set 7 | warmbad
# Processing Record 17 of Set 7 | general conesa
# Processing Record 18 of Set 7 | zhongxiang
# Processing Record 19 of Set 7 | jabor
# Processing Record 20 of Set 7 | plastun
# Processing Record 21 of Set 7 | broken hill
# Processing Record 22 of Set 7 | nizhnesortymskiy
# Processing Record 23 of Set 7 | qaisumah
# Processing Record 24 of Set 7 | palmer
# Processing Record 25 of Set 7 | el nido
# Processing Record 26 of Set 7 | sao joao da barra
# Processing Record 27 of Set 7 | camiri
# Processing Record 28 of Set 7 | al fashn
# Processing Record 29 of Set 7 | tomatlan
# Processing Record 30 of Set 7 | mahad
# Processing Record 31 of Set 7 | howard springs
# Processing Record 32 of Set 7 | hadibu
# Processing Record 33 of Set 7 | pandan
# Processing Record 34 of Set 7 | kiunga
# Processing Record 35 of Set 7 | anna regina
# Processing Record 36 of Set 7 | aylmer
# Processing Record 37 of Set 7 | saratamata
# City not found. Skipping...
# Processing Record 38 of Set 7 | puerto san carlos
# City not found. Skipping...
# Processing Record 39 of Set 7 | tazovsky
# Processing Record 40 of Set 7 | kambove
# Processing Record 41 of Set 7 | ar rabiyah
# Processing Record 42 of Set 7 | pangody
# Processing Record 43 of Set 7 | gornopravdinsk
# Processing Record 44 of Set 7 | el calafate
# Processing Record 45 of Set 7 | saynshand
# Processing Record 46 of Set 7 | languyan
# Processing Record 47 of Set 7 | betare oya
# Processing Record 48 of Set 7 | sale
# Processing Record 49 of Set 7 | village of oak creek (big park)
# Processing Record 0 of Set 8 | tiznit
# City not found. Skipping...
# Processing Record 1 of Set 8 | makarov
# Processing Record 2 of Set 8 | kiruna
# Processing Record 3 of Set 8 | sahavato
# City not found. Skipping...
# Processing Record 4 of Set 8 | chauk
# Processing Record 5 of Set 8 | belaya kholunitsa
# Processing Record 6 of Set 8 | vuktyl
# Processing Record 7 of Set 8 | rio preto da eva
# Processing Record 8 of Set 8 | uyo
# Processing Record 9 of Set 8 | hayma'
# City not found. Skipping...
# Processing Record 10 of Set 8 | bubaque
# Processing Record 11 of Set 8 | weno
# Processing Record 12 of Set 8 | nha trang
# Processing Record 13 of Set 8 | mandiana
# Processing Record 14 of Set 8 | naze
# Processing Record 15 of Set 8 | bodo
# Processing Record 16 of Set 8 | camacupa
# Processing Record 17 of Set 8 | pamandzi
# Processing Record 18 of Set 8 | la ronge
# Processing Record 19 of Set 8 | kaduy
# Processing Record 20 of Set 8 | mangochi
# Processing Record 21 of Set 8 | deder
# Processing Record 22 of Set 8 | reggane
# Processing Record 23 of Set 8 | cahri
# City not found. Skipping...
# Processing Record 24 of Set 8 | eregli
# Processing Record 25 of Set 8 | klyuchi
# Processing Record 26 of Set 8 | kikwit
# Processing Record 27 of Set 8 | mournies
# Processing Record 28 of Set 8 | pacasmayo
# Processing Record 29 of Set 8 | pantai cenang
# City not found. Skipping...
# Processing Record 30 of Set 8 | santa terezinha
# Processing Record 31 of Set 8 | brigantine
# Processing Record 32 of Set 8 | bogale
# Processing Record 33 of Set 8 | vila franca do campo
# Processing Record 34 of Set 8 | kuala terengganu
# Processing Record 35 of Set 8 | vila velha
# Processing Record 36 of Set 8 | baranivka
# Processing Record 37 of Set 8 | katsuura
# Processing Record 38 of Set 8 | tsiombe
# Processing Record 39 of Set 8 | palikir - national government center
# Processing Record 40 of Set 8 | toamasina
# Processing Record 41 of Set 8 | nchelenge
# Processing Record 42 of Set 8 | uliastay
# Processing Record 43 of Set 8 | puerto leguizamo
# Processing Record 44 of Set 8 | uribia
# Processing Record 45 of Set 8 | haiku-pauwela
# Processing Record 46 of Set 8 | el colomo
# Processing Record 47 of Set 8 | mount isa
# Processing Record 48 of Set 8 | necochea
# Processing Record 49 of Set 8 | ust'-kulom
# Processing Record 0 of Set 9 | praia da vitoria
# Processing Record 1 of Set 9 | altay
# Processing Record 2 of Set 9 | kenai
# Processing Record 3 of Set 9 | sarmiento
# Processing Record 4 of Set 9 | namtsy
# Processing Record 5 of Set 9 | harburg
# Processing Record 6 of Set 9 | errachidia
# Processing Record 7 of Set 9 | laojunmiao
# Processing Record 8 of Set 9 | fale old settlement
# Processing Record 9 of Set 9 | shalkar
# Processing Record 10 of Set 9 | kenora
# Processing Record 11 of Set 9 | oroqen zizhiqi
# Processing Record 12 of Set 9 | alpine
# Processing Record 13 of Set 9 | san jose village
# City not found. Skipping...
# Processing Record 14 of Set 9 | east london
# Processing Record 15 of Set 9 | ust'-kalmanka
# Processing Record 16 of Set 9 | kataragama
# City not found. Skipping...
# Processing Record 17 of Set 9 | timimoun
# Processing Record 18 of Set 9 | axim
# Processing Record 19 of Set 9 | turiacu
# Processing Record 20 of Set 9 | mtambile
# Processing Record 21 of Set 9 | rebrikha
# Processing Record 22 of Set 9 | east ballina
# Processing Record 23 of Set 9 | babana
# Processing Record 24 of Set 9 | devinuwara
# City not found. Skipping...
# Processing Record 25 of Set 9 | la'ie
# Processing Record 26 of Set 9 | pasvalys
# Processing Record 27 of Set 9 | ebetsu
# Processing Record 28 of Set 9 | blythe
# Processing Record 29 of Set 9 | port isabel
# Processing Record 30 of Set 9 | muynoq
# Processing Record 31 of Set 9 | cartagena
# Processing Record 32 of Set 9 | huanta
# Processing Record 33 of Set 9 | kincardine
# Processing Record 34 of Set 9 | launceston
# Processing Record 35 of Set 9 | baikunthpur
# Processing Record 36 of Set 9 | farim
# Processing Record 37 of Set 9 | flying fish cove
# Processing Record 38 of Set 9 | el bauga
# Processing Record 39 of Set 9 | petropavlovka
# Processing Record 40 of Set 9 | crane
# Processing Record 41 of Set 9 | mesquite
# Processing Record 42 of Set 9 | mata-utu
# Processing Record 43 of Set 9 | arno
# Processing Record 44 of Set 9 | olanchito
# Processing Record 45 of Set 9 | djambala
# Processing Record 46 of Set 9 | pikalevo
# Processing Record 47 of Set 9 | tsetserleg
# Processing Record 48 of Set 9 | sinop
# Processing Record 49 of Set 9 | dalton
# Processing Record 0 of Set 10 | bardai
# Processing Record 1 of Set 10 | aksu
# Processing Record 2 of Set 10 | pariaman
# Processing Record 3 of Set 10 | tangalle
# Processing Record 4 of Set 10 | hashtrud
# Processing Record 5 of Set 10 | whangarei
# Processing Record 6 of Set 10 | kidal
# Processing Record 7 of Set 10 | bamboo flat
# Processing Record 8 of Set 10 | divnoye
# Processing Record 9 of Set 10 | tanjung selor
# City not found. Skipping...
# Processing Record 10 of Set 10 | cusseta
# Processing Record 11 of Set 10 | icano
# Processing Record 12 of Set 10 | dudinka
# Processing Record 13 of Set 10 | tansen
# Processing Record 14 of Set 10 | angra do heroismo
# Processing Record 15 of Set 10 | wladyslawowo
# Processing Record 16 of Set 10 | plettenberg bay
# Processing Record 17 of Set 10 | zwedru
# Processing Record 18 of Set 10 | taroa
# Processing Record 19 of Set 10 | vlore
# Processing Record 20 of Set 10 | fort abbas
# Processing Record 21 of Set 10 | kavieng
# Processing Record 22 of Set 10 | sinabang
# Processing Record 23 of Set 10 | buckhannon
# Processing Record 24 of Set 10 | al jawf
# Processing Record 25 of Set 10 | al hudaydah
# Processing Record 26 of Set 10 | kalmunai
# Processing Record 27 of Set 10 | alofi
# Processing Record 28 of Set 10 | colesberg
# Processing Record 29 of Set 10 | tatishchevo
# Processing Record 30 of Set 10 | azna
# Processing Record 31 of Set 10 | shalqar
# Processing Record 32 of Set 10 | igarka
# Processing Record 33 of Set 10 | shimoda
# Processing Record 34 of Set 10 | mogadishu
# Processing Record 35 of Set 10 | nikolayevsk-on-amure
# Processing Record 36 of Set 10 | sakakah
# Processing Record 37 of Set 10 | bougouni
# Processing Record 38 of Set 10 | osorno
# Processing Record 39 of Set 10 | visby
# Processing Record 40 of Set 10 | batticaloa
# Processing Record 41 of Set 10 | dolores
# Processing Record 42 of Set 10 | dali
# Processing Record 43 of Set 10 | verkhnevilyuysk
# Processing Record 44 of Set 10 | tamanrasset
# Processing Record 45 of Set 10 | bir hadaj
# City not found. Skipping...
# Processing Record 46 of Set 10 | la passe
# Processing Record 47 of Set 10 | usogorsk
# Processing Record 48 of Set 10 | lautoka
# Processing Record 49 of Set 10 | capinota
# Processing Record 0 of Set 11 | niquero
# Processing Record 1 of Set 11 | magadan
# Processing Record 2 of Set 11 | kiffa
# Processing Record 3 of Set 11 | antofagasta
# Processing Record 4 of Set 11 | panguipulli
# Processing Record 5 of Set 11 | roma
# Processing Record 6 of Set 11 | praia
# Processing Record 7 of Set 11 | lorengau
# Processing Record 8 of Set 11 | santiago de cao
# Processing Record 9 of Set 11 | khalis
# Processing Record 10 of Set 11 | awjilah
# Processing Record 11 of Set 11 | herkimer
# Processing Record 12 of Set 11 | guane
# Processing Record 13 of Set 11 | kangding
# Processing Record 14 of Set 11 | saint-pol-de-leon
# Processing Record 15 of Set 11 | osh
# Processing Record 16 of Set 11 | bonthe
# Processing Record 17 of Set 11 | sitka
# Processing Record 18 of Set 11 | toledo
# Processing Record 19 of Set 11 | keflavik
# Processing Record 20 of Set 11 | nelson bay
# Processing Record 21 of Set 11 | miracema do tocantins
# Processing Record 22 of Set 11 | segezha
# Processing Record 23 of Set 11 | turpan
# Processing Record 24 of Set 11 | paita
# Processing Record 25 of Set 11 | myitkyina
# Processing Record 26 of Set 11 | yangon
# Processing Record 27 of Set 11 | khorixas
# Processing Record 28 of Set 11 | bikenibeu village
# Processing Record 29 of Set 11 | nuuk
# Processing Record 30 of Set 11 | kashgar
# Processing Record 31 of Set 11 | juanjui
# Processing Record 32 of Set 11 | sokoni
# Processing Record 33 of Set 11 | paratinga
# Processing Record 34 of Set 11 | rongelap
# Processing Record 35 of Set 11 | gadzhiyevo
# Processing Record 36 of Set 11 | tura
# Processing Record 37 of Set 11 | port saint john's
# Processing Record 38 of Set 11 | veinticinco de mayo
# Processing Record 39 of Set 11 | villa alberto andres alvarado aramburo
# City not found. Skipping...
# Processing Record 40 of Set 11 | kilindoni
# Processing Record 41 of Set 11 | levuka
# Processing Record 42 of Set 11 | urangan
# Processing Record 43 of Set 11 | nar'yan-mar
# Processing Record 44 of Set 11 | smirnykh
# Processing Record 45 of Set 11 | gebeit
# Processing Record 46 of Set 11 | aykhal
# Processing Record 47 of Set 11 | magong
# Processing Record 48 of Set 11 | warman
# Processing Record 49 of Set 11 | cold lake
# Processing Record 0 of Set 12 | saint-leu
# Processing Record 1 of Set 12 | brisas de zicatela
# Processing Record 2 of Set 12 | barbastro
# Processing Record 3 of Set 12 | nema
# Processing Record 4 of Set 12 | margarita belen
# Processing Record 5 of Set 12 | checker hall
# City not found. Skipping...
# Processing Record 6 of Set 12 | hirara
# Processing Record 7 of Set 12 | pemba
# Processing Record 8 of Set 12 | melfort
# Processing Record 9 of Set 12 | kisi
# Processing Record 10 of Set 12 | uglegorsk
# Processing Record 11 of Set 12 | i-n-salah
# Processing Record 12 of Set 12 | homer
# Processing Record 13 of Set 12 | babolsar
# Processing Record 14 of Set 12 | senador jose porfirio
# Processing Record 15 of Set 12 | taupo
# Processing Record 16 of Set 12 | el jadid
# Processing Record 17 of Set 12 | hecun
# Processing Record 18 of Set 12 | nantucket
# Processing Record 19 of Set 12 | tacotalpa
# Processing Record 20 of Set 12 | zaozersk
# Processing Record 21 of Set 12 | kalabo
# Processing Record 22 of Set 12 | mukwonago
# Processing Record 23 of Set 12 | rakops
# Processing Record 24 of Set 12 | san andres
# Processing Record 25 of Set 12 | dryden
# Processing Record 26 of Set 12 | queenstown
# Processing Record 27 of Set 12 | cururupu
# Processing Record 28 of Set 12 | kananga
# Processing Record 29 of Set 12 | alotau
# City not found. Skipping...
# Processing Record 30 of Set 12 | plouzane
# Processing Record 31 of Set 12 | lai chau
# Processing Record 32 of Set 12 | helena
# Processing Record 33 of Set 12 | phan thiet
# Processing Record 34 of Set 12 | la jagua de ibirico
# Processing Record 35 of Set 12 | qui nhon
# Processing Record 36 of Set 12 | floro
# Processing Record 37 of Set 12 | umluj
# Processing Record 38 of Set 12 | fasano
# Processing Record 39 of Set 12 | ma'rib
# Processing Record 40 of Set 12 | midvagur
# Processing Record 41 of Set 12 | papao
# Processing Record 42 of Set 12 | ambagarh chauki
# Processing Record 43 of Set 12 | am djarass
# City not found. Skipping...
# Processing Record 44 of Set 12 | tindouf
# Processing Record 45 of Set 12 | pierre
# Processing Record 46 of Set 12 | tarawa
# Processing Record 47 of Set 12 | oudtshoorn
# Processing Record 48 of Set 12 | boa vista
# Processing Record 49 of Set 12 | sao jose do rio pardo
# Processing Record 0 of Set 13 | sotouboua
# Processing Record 1 of Set 13 | guiria
# City not found. Skipping...
# Processing Record 2 of Set 13 | kharp
# Processing Record 3 of Set 13 | manicore
# Processing Record 4 of Set 13 | phalaborwa
# Processing Record 5 of Set 13 | kichmengskiy gorodok
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.rename(columns={'City.1': 'City'})
# Convert the Max Temperature from Kelvin to Celsius
city_data_df['Max Temp'] = city_data_df['Max Temp'] - 273.15
city_data_df
# Show Record Count
city_data_df.count()
# Out:
# City          578
# Lat           578
# Lng           578
# Max Temp      578
# Humidity      578
# Cloudiness    578
# Wind Speed    578
# Country       578
# Date          578
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          olonkinbyen  70.9221   -8.7187     -3.41        83          98
# 1        labrador city  52.9463  -66.9114     -0.05        43          40
# 2       port elizabeth -33.9180   25.5701     20.61        96          20
# 3  san antonio de pale  -1.4014    5.6325     28.99        81          70
# 4          vilyuchinsk  52.9306  158.4028      2.15        85          66
#
#    Wind Speed Country        Date
# 0        6.75      SJ  1713735174
# 1        3.09      CA  1713735010
# 2        4.12      ZA  1713735175
# 3        2.85      GQ  1713735176
# 4        0.37      RU  1713735176

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output data/cities.csv", index_label="City ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output data/cities.csv", index_col="City ID")

# Display sample data
city_data_df.head()
# Out:
#                         City      Lat       Lng  Max Temp  Humidity  \
# City ID
# 0                olonkinbyen  70.9221   -8.7187     -3.41        83
# 1              labrador city  52.9463  -66.9114     -0.05        43
# 2             port elizabeth -33.9180   25.5701     20.61        96
# 3        san antonio de pale  -1.4014    5.6325     28.99        81
# 4                vilyuchinsk  52.9306  158.4028      2.15        85
#
#          Cloudiness  Wind Speed Country        Date
# City ID
# 0                98        6.75      SJ  1713735174
# 1                40        3.09      CA  1713735010
# 2                20        4.12      ZA  1713735175
# 3                70        2.85      GQ  1713735176
# 4                66        0.37      RU  1713735176

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
lat_temp_df = city_data_df[['Lat','Max Temp']]
lat_temp_df
lat_temp_df.plot(kind="scatter",x='Lat',y='Max Temp',edgecolor='black',s=30)

# Incorporate the other graph properties
plt.xlabel('Latitute')
plt.ylabel('Max Temperature (C)')
plt.title('City Max Latitute vs. Temperature (2024-04-21)')
plt.grid()

# Save the figure
plt.savefig("output data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
lat_hum_df = city_data_df[['Lat','Humidity']]
lat_hum_df
lat_hum_df.plot(kind="scatter",x='Lat',y='Humidity',edgecolor='black',s=30)

# Incorporate the other graph properties
plt.xlabel('Latitute')
plt.ylabel('Humidity (%)')
plt.title('City Max Latitute vs. Humidity (2024-04-21)')
plt.grid()

# Save the figure
plt.savefig("output data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
lat_cloud_df = city_data_df[['Lat','Cloudiness']]
lat_cloud_df
lat_cloud_df.plot(kind="scatter",x='Lat',y='Cloudiness',edgecolor='black',s=30)

# Incorporate the other graph properties
plt.xlabel('Latitute')
plt.ylabel('Cloudiness (%)')
plt.title('City Max Latitute vs. Cloudiness (2024-04-21)')
plt.grid()

# Save the figure
plt.savefig("output data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
lat_wind_df = city_data_df[['Lat','Wind Speed']]
lat_wind_df
lat_wind_df.plot(kind="scatter",x='Lat',y='Wind Speed',edgecolor='black',s=30)

# Incorporate the other graph properties
plt.xlabel('Latitute')
plt.ylabel('Wind Speed (m/s)')
plt.title('City Max Latitute vs. Wind Speed (2024-04-21)')
plt.grid()

# Save the figure
plt.savefig("output data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[(city_data_df['Lat']>=0)]
# Display sample data
northern_hemi_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City ID
# 0          olonkinbyen  70.9221   -8.7187     -3.41        83          98
# 1        labrador city  52.9463  -66.9114     -0.05        43          40
# 4          vilyuchinsk  52.9306  158.4028      2.15        85          66
# 6              college  64.8569 -147.8028     12.18        33           0
# 7             benghazi  32.1167   20.0667     25.38        24         100
#
#          Wind Speed Country        Date
# City ID
# 0              6.75      SJ  1713735174
# 1              3.09      CA  1713735010
# 4              0.37      RU  1713735176
# 6              0.00      US  1713734938
# 7             13.38      LY  1713735178

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[(city_data_df['Lat']<0)]

# Display sample data
southern_hemi_df.head()
# Out:
#                         City      Lat       Lng  Max Temp  Humidity  \
# City ID
# 2             port elizabeth -33.9180   25.5701     20.61        96
# 3        san antonio de pale  -1.4014    5.6325     28.99        81
# 5                    ushuaia -54.8000  -68.3000      6.81        76
# 8                  adamstown -25.0660 -130.1015     22.36        71
# 11                 grytviken -54.2811  -36.5092      2.92        95
#
#          Cloudiness  Wind Speed Country        Date
# City ID
# 2                20        4.12      ZA  1713735175
# 3                70        2.85      GQ  1713735176
# 5                40       12.35      AR  1713735078
# 8                83        9.09      PN  1713734927
# 11              100        2.88      GS  1713734895

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(10,-20),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (C)')
print("r-value =", abs(rvalue))
plt.show()
# Out:
# r-value = 0.8369988997692455

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,26.95),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (C)')
print("r-value =", abs(rvalue))
plt.show()
# Out:
# r-value = 0.8222483326596128

# %% [markdown]
# **Discussion about the linear relationship:** Latitute and Temperature have a strong correlation as the absolute value of the r-value is > 0.7 for both the northern and southern hemispheres.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(45,5),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
print("r-value =", abs(rvalue))
plt.show()
# Out:
# r-value = 0.08954900622114018

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-22,25),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
print("r-value =", abs(rvalue))
plt.show()
# Out:
# r-value = 0.18881907455316724

# %% [markdown]
# **Discussion about the linear relationship:** There appears to be no correlation between Latitude and Humididty. The absolute value of the r-value is less than 0.3 for both the northern and southern hemispheres.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(45,45),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
print("r-value =", abs(rvalue))
plt.show()
# Out:
# r-value = 0.08966840519107669

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-25,50),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
print("r-value =", abs(rvalue))
plt.show()
# Out:
# r-value = 0.19333248822033508

# %% [markdown]
# **Discussion about the linear relationship:** There appears to be no correlation between Latitude and Cloudiness. The absolute value of the r-value is less than 0.3 for both the northern and southern hemispheres.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(25,16),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
print("r-value =", abs(rvalue))
plt.show()
# Out:
# r-value = 0.042375785852611224

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-30,11),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
print("r-value =", abs(rvalue))
plt.show()
# Out:
# r-value = 0.33553383315450297

# %% [markdown]
# **Discussion about the linear relationship:** There does not appears to be a correlation between wind speed and latitude as can be seen by the northern hemisphere r-value. The southern hemisphere r-value shows a weak correlation but it is on the lower end of the spectrum.
